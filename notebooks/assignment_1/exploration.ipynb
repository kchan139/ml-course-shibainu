# %% [markdown]
# # Initialize

# %%
import sys
import os

# Append the absolute path of the root directory of the project
notebook_path = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_path, '..', '..'))

# Add the root directory to sys.path
sys.path.append(project_root)

# Import necessary libraries
import pandas as pd
from src.data.make_dataset import DatasetLoader
from src.visualization.visualize import Visualizer

# %% [markdown]
# # Create path to the Dataset

# %%
# Path to the dataset, considering the notebook's location
dataset_path = os.path.join(project_root, 'dataset', 'raw', 'all-data.csv')

# Load the dataset using DatasetLoader
# loader = DatasetLoader()
# df = loader.load_data(dataset_path)
df = pd.read_csv(dataset_path)

# Clean column names by stripping leading/trailing spaces
df.columns = df.columns.str.strip()

# Display the first few rows of the dataset
df.head()
# Out:
#   Sentiment                                      News Headline
# 0  positive  The firm has seen substantial revenue growth, ...
# 1  positive  The recent partnership is expected to signific...
# 2  positive  Increased international sales have propelled t...
# 3  positive  The company's proactive customer engagement ha...
# 4  positive  A successful product launch has already starte...

# %% [markdown]
# # Plot the Class Distribution

# %%
visualizer = Visualizer()

visualizer.plot_class_distribution(df)

# %% [markdown]
# # Generate Word Clouds

# %%
visualizer.generate_word_cloud(df, 'positive')

visualizer.generate_word_cloud(df, 'negative')

visualizer.generate_word_cloud(df, 'neutral')

# %% [markdown]
# # Plot Text Length Distribution

# %%
visualizer.plot_text_length_distribution(df)

# %% [markdown]
# # Plot Top N-Grams

# %%
visualizer.plot_top_ngrams(df, 4)
